# %%
class Teams():
    def __init__(self, teamName, MP, W, D, L, GF, GA, GD, Pts):
        self.teamName = teamName
        self.MP = MP
        self.W = W
        self.D = D
        self.L = L
        self.GF = GF
        self.GA = GA
        self.GD = GD
        self.Pts = Pts
Netherlands = Teams('Netherlands', 3, 2, 1, 0, 5, 1, 4, 7)
Sengal = Teams('Sengal', 3, 2, 0, 1, 5, 4, 1, 6)
Ecuador = Teams('Ecuador', 3, 1, 1, 1, 4, 3, 1, 4)
Qatar = Teams('Qatar', 3, 0, 0, 3, 1, 7, -6, 0)
England = Teams('England', 3, 2, 1, 0, 9, 2, 7, 7)
USA = Teams('USA', 3, 1, 2, 0, 2, 1, 1, 5)
Iran = Teams('Iran', 3, 1, 0, 2, 4, 7, -3, 3)
Wales = Teams('Wales', 3, 0, 1, 2, 1, 6, -5, 1)
Argentina = Teams('Argentina', 3, 2, 0, 1, 5, 2, 3, 6)
Poland = Teams('Poland', 3, 1, 1, 1, 2, 2, 0, 4)
Mexico = Teams('Mexico', 3, 1, 1, 1, 2, 3, -1, 4)
Saudi_Arabia = Teams('Saudi Arabia', 3, 1, 0, 2, 3, 5, -2, 3)
France = Teams('France', 3, 2, 0, 1, 6, 3, 3, 6)
Australia = Teams('Australia', 3, 2, 0, 1, 3, 4, -1, 6)
Tunisia = Teams('Tunisia', 3, 1, 1, 1, 1, 1, 0, 4)
Denmark = Teams('Denmark', 3, 0, 1, 2, 1, 3, 2, 1)
Japan = Teams('Japan', 3, 2, 0, 1, 4, 3, 1, 6)
Spain = Teams('Spain', 3, 1, 1, 1, 9, 3, 6, 4)
Germany = Teams('Germany', 3, 1, 1, 1, 6, 5, 1, 4)
Costa_Rica = Teams('Costa Rica', 3, 1, 0, 2, 3, 11, -8, 3)
Morocco = Teams('Morocco', 3, 2, 1, 0, 4, 1, 3, 7)
Croatia = Teams('Croatia', 3, 1, 2, 0, 4, 1, 3, 5)
Belgium = Teams('Belgium', 3, 1, 1, 1, 1, 2, 1, 4)
Canada = Teams('Canada', 3, 0, 0, 3, 2, 7, 5, 0)
Brazil = Teams('Brazil', 3, 2, 0, 1, 3, 1, 2, 6)
Switzerland = Teams('Switzerland', 3, 2, 0, 1, 4, 3, 1, 6)
Cameroon = Teams('Cameroon', 3, 1, 1, 1, 4, 4, 0, 4)
Serbia = Teams('Serbia', 3, 0, 1, 2, 5, 8, -3, 1)
Portugal = Teams('Portugal', 3, 2, 0, 1, 6, 4, 2, 6)
South_Korea = Teams('South Korea', 3, 1, 1, 1, 4, 4, 0, 4)
Uruguay = Teams('Uruguay', 3, 1, 1, 1, 2, 2, 0, 4)
Ghana = Teams('Ghana', 3, 1, 0, 2, 5, 7, -2, 3)
#---------------------------------------------------------------------------------------------------------------------
yesNo = input("Do you want to input your own match results, yes/no: ")
print("\n")

if (yesNo == "yes"):
    Netherlands.W = input("How many games did the Netherlands WIN? ")
    Netherlands.L = input("How many games did the Netherlands LOSE? ")
    Netherlands.D = input("How many games did the Netherlands DRAW? ")
    Netherlands.GD = input("What is the goal diffrence for the Netherlands? ")
    Netherlands.Pts = (int(Netherlands.W)*3 + int(Netherlands.D))
    print("\n")
    
    Sengal.W = input("How many games did the Sengal WIN? ")
    Sengal.L = input("How many games did the Sengal LOSE? ")
    Sengal.D = input("How many games did the Sengal DRAW? ")
    Sengal.GD = input("What is the goal diffrence for the Sengal? ")
    Sengal.Pts = (int(Sengal.W)*3 + int(Sengal.D))
    print("\n")
    
    Ecuador.W = input("How many games did the Ecuador WIN? ")
    Ecuador.L = input("How many games did the Ecuador LOSE? ")
    Ecuador.D = input("How many games did the Ecuador DRAW? ")
    Ecuador.GD = input("What is the goal diffrence for the Ecuador? ")
    Ecuador.Pts = (int(Ecuador.W)*3 + int(Ecuador.D))
    print("\n")
    
    Qatar.W = input("How many games did the Qatar WIN? ")
    Qatar.L = input("How many games did the Qatar LOSE? ")
    Qatar.D = input("How many games did the Qatar DRAW? ")
    Qatar.GD = input("What is the goal diffrence for the Qatar? ")
    Qatar.Pts = (int(Qatar.W)*3 + int(Qatar.D))
    print("\n")
    
    England.W = input("How many games did the England WIN? ")
    England.L = input("How many games did the England LOSE? ")
    England.D = input("How many games did the England DRAW? ")
    England.GD = input("What is the goal diffrence for the England? ")
    England.Pts = (int(England.W)*3 + int(England.D))
    print("\n")
    
    USA.W = input("How many games did the USA WIN? ")
    USA.L = input("How many games did the USA LOSE? ")
    USA.D = input("How many games did the USA DRAW? ")
    USA.GD = input("What is the goal diffrence for the USA? ")
    USA.Pts = (int(USA.W)*3 + int(USA.D))
    print("\n")
    
    Iran.W = input("How many games did the Iran WIN? ")
    Iran.L = input("How many games did the Iran LOSE? ")
    Iran.D = input("How many games did the Iran DRAW? ")
    Iran.GD = input("What is the goal diffrence for the Iran? ")
    Iran.Pts = (int(Iran.W)*3 + int(Iran.D))
    print("\n")
    
    Wales.W = input("How many games did the Wales WIN? ")
    Wales.L = input("How many games did the Wales LOSE? ")
    Wales.D = input("How many games did the Wales DRAW? ")
    Wales.GD = input("What is the goal diffrence for the Wales? ")
    Wales.Pts = (int(Wales.W)*3 + int(Wales.D))
    print("\n")
    
    Argentina.W = input("How many games did the Argentina WIN? ")
    Argentina.L = input("How many games did the Argentina LOSE? ")
    Argentina.D = input("How many games did the Argentina DRAW? ")
    Argentina.GD = input("What is the goal diffrence for the Argentina? ")
    Argentina.Pts = (int(Argentina.W)*3 + int(Argentina.D))
    print("\n")
    
    Poland.W = input("How many games did the Poland WIN? ")
    Poland.L = input("How many games did the Poland LOSE? ")
    Poland.D = input("How many games did the Poland DRAW? ")
    Poland.GD = input("What is the goal diffrence for the Poland? ")
    Poland.Pts = (int(Poland.W)*3 + int(Poland.D))
    print("\n")
    
    Mexico.W = input("How many games did the Mexico WIN? ")
    Mexico.L = input("How many games did the Mexico LOSE? ")
    Mexico.D = input("How many games did the Mexico DRAW? ")
    Mexico.GD = input("What is the goal diffrence for the Mexico? ")
    Mexico.Pts = (int(Mexico.W)*3 + int(Mexico.D))
    print("\n")
    
    Saudi_Arabia.W = input("How many games did the Saudi Arabia WIN? ")
    Saudi_Arabia.L = input("How many games did the Saudi Arabia LOSE? ")
    Saudi_Arabia.D = input("How many games did the Saudi Arabia DRAW? ")
    Saudi_Arabia.GD = input("What is the goal diffrence for the Saudi Arabia? ")
    Saudi_Arabia.Pts = (int(Saudi_Arabia.W)*3 + int(Saudi_Arabia.D))
    print("\n")
    
    France.W = input("How many games did the France WIN? ")
    France.L = input("How many games did the France LOSE? ")
    France.D = input("How many games did the France DRAW? ")
    France.GD = input("What is the goal diffrence for the France? ")
    France.Pts = (int(France.W)*3 + int(France.D))
    print("\n")
    
    Australia.W = input("How many games did the Australia WIN? ")
    Australia.L = input("How many games did the Australia LOSE? ")
    Australia.D = input("How many games did the Australia DRAW? ")
    Australia.GD = input("What is the goal diffrence for the Australia? ")
    Australia.Pts = (int(Australia.W)*3 + int(Australia.D))
    print("\n")
    
    Tunisia.W = input("How many games did the Tunisia WIN? ")
    Tunisia.L = input("How many games did the Tunisia LOSE? ")
    Tunisia.D = input("How many games did the Tunisia DRAW? ")
    Tunisia.GD = input("What is the goal diffrence for the Tunisia? ")
    Tunisia.Pts = (int(Tunisia.W)*3 + int(Tunisia.D))
    print("\n")
    
    Denmark.W = input("How many games did the Denmark WIN? ")
    Denmark.L = input("How many games did the Denmark LOSE? ")
    Denmark.D = input("How many games did the Denmark DRAW? ")
    Denmark.GD = input("What is the goal diffrence for the Denmark? ")
    Denmark.Pts = (int(Denmark.W)*3 + int(Denmark.D))
    print("\n")
    
    Japan.W = input("How many games did the Japan WIN? ")
    Japan.L = input("How many games did the Japan LOSE? ")
    Japan.D = input("How many games did the Japan DRAW? ")
    Japan.GD = input("What is the goal diffrence for the Japan? ")
    Japan.Pts = (int(Japan.W)*3 + int(Japan.D))
    print("\n")
    
    Spain.W = input("How many games did the Spain WIN? ")
    Spain.L = input("How many games did the Spain LOSE? ")
    Spain.D = input("How many games did the Spain DRAW? ")
    Spain.GD = input("What is the goal diffrence for the Spain? ")
    Spain.Pts = (int(Spain.W)*3 + int(Spain.D))
    print("\n")
    
    Germany.W = input("How many games did the Germany WIN? ")
    Germany.L = input("How many games did the Germany LOSE? ")
    Germany.D = input("How many games did the Germany DRAW? ")
    Germany.GD = input("What is the goal diffrence for the Germany? ")
    Germany.Pts = (int(Germany.W)*3 + int(Germany.D))
    print("\n")
    
    Costa_Rica.W = input("How many games did the Costa Rica WIN? ")
    Costa_Rica.L = input("How many games did the Costa Rica LOSE? ")
    Costa_Rica.D = input("How many games did the Costa Rica DRAW? ")
    Costa_Rica.GD = input("What is the goal diffrence for the Costa Rica? ")
    Costa_Rica.Pts = (int(Costa_Rica.W)*3 + int(Costa_Rica.D))
    print("\n")
    
    Morocco.W = input("How many games did the Morocco WIN? ")
    Morocco.L = input("How many games did the Morocco LOSE? ")
    Morocco.D = input("How many games did the Morocco DRAW? ")
    Morocco.GD = input("What is the goal diffrence for the Morocco? ")
    Morocco.Pts = (int(Morocco.W)*3 + int(Morocco.D))
    print("\n")
    
    Croatia.W = input("How many games did the Croatia WIN? ")
    Croatia.L = input("How many games did the Croatia LOSE? ")
    Croatia.D = input("How many games did the Croatia DRAW? ")
    Croatia.GD = input("What is the goal diffrence for the Croatia? ")
    Croatia.Pts = (int(Croatia.W)*3 + int(Croatia.D))
    print("\n")
    
    Belgium.W = input("How many games did the Belgium WIN? ")
    Belgium.L = input("How many games did the Belgium LOSE? ")
    Belgium.D = input("How many games did the Belgium DRAW? ")
    Belgium.GD = input("What is the goal diffrence for the Belgium? ")
    Belgium.Pts = (int(Belgium.W)*3 + int(Belgium.D))
    print("\n")
    
    Canada.W = input("How many games did the Canada WIN? ")
    Canada.L = input("How many games did the Canada LOSE? ")
    Canada.D = input("How many games did the Canada DRAW? ")
    Canada.GD = input("What is the goal diffrence for the Canada? ")
    Canada.Pts = (int(Canada.W)*3 + int(Canada.D))
    print("\n")
    
    Brazil.W = input("How many games did the Brazil WIN? ")
    Brazil.L = input("How many games did the Brazil LOSE? ")
    Brazil.D = input("How many games did the Brazil DRAW? ")
    Brazil.GD = input("What is the goal diffrence for the Brazil? ")
    Brazil.Pts = (int(Brazil.W)*3 + int(Brazil.D))
    print("\n")
    
    Switzerland.W = input("How many games did the Switzerland WIN? ")
    Switzerland.L = input("How many games did the Switzerland LOSE? ")
    Switzerland.D = input("How many games did the Switzerland DRAW? ")
    Switzerland.GD = input("What is the goal diffrence for the Switzerland? ")
    Switzerland.Pts = (int(Switzerland.W)*3 + int(Switzerland.D))
    print("\n")
    
    Cameroon.W = input("How many games did the Cameroon WIN? ")
    Cameroon.L = input("How many games did the Cameroon LOSE? ")
    Cameroon.D = input("How many games did the Cameroon DRAW? ")
    Cameroon.GD = input("What is the goal diffrence for the Cameroon? ")
    Cameroon.Pts = (int(Cameroon.W)*3 + int(Cameroon.D))
    print("\n")
    
    Serbia.W = input("How many games did the Serbia WIN? ")
    Serbia.L = input("How many games did the Serbia LOSE? ")
    Serbia.D = input("How many games did the Serbia DRAW? ")
    Serbia.GD = input("What is the goal diffrence for the Serbia? ")
    Serbia.Pts = (int(Serbia.W)*3 + int(Serbia.D))
    print("\n")
    
    Portugal.W = input("How many games did the Portugal WIN? ")
    Portugal.L = input("How many games did the Portugal LOSE? ")
    Portugal.D = input("How many games did the Portugal DRAW? ")
    Portugal.GD = input("What is the goal diffrence for the Portugal? ")
    Portugal.Pts = (int(Portugal.W)*3 + int(Portugal.D))
    print("\n")
    
    South_Korea.W = input("How many games did the South Korea WIN? ")
    South_Korea.L = input("How many games did the South Korea LOSE? ")
    South_Korea.D = input("How many games did the South Korea DRAW? ")
    South_Korea.GD = input("What is the goal diffrence for the South Korea? ")
    South_Korea.Pts = (int(South_Korea.W)*3 + int(South_Korea.D))
    print("\n")
    
    Uruguay.W = input("How many games did the Uruguay WIN? ")
    Uruguay.L = input("How many games did the Uruguay LOSE? ")
    Uruguay.D = input("How many games did the Uruguay DRAW? ")
    Uruguay.GD = input("What is the goal diffrence for the Uruguay? ")
    Uruguay.Pts = (int(Uruguay.W)*3 + int(Uruguay.D))
    print("\n")
    
    Ghana.W = input("How many did games did the Ghana WIN? ")
    Ghana.L = input("How many did games did the Ghana LOSE? ")
    Ghana.D = input("How many did games did the Ghana DRAW? ")
    Ghana.GD = input("What is the goal diffrence for the Ghana? ")
    Ghana.Pts = (int(Ghana.W)*3 + int(Ghana.D))
    print("\n")
#---------------------------------------------------------------------------------------------------------------------
else:
    print("The team stage results are:")
    print("Netherlands MP-3, Wins-2, draws-1, loses-0 , GF-5, GA-1, GD-4, Pts-7")
    print("Sengal MP-3, Wins-2, draws-0, loses-1, GF-5, GA-4, GD-1, Pts-6")
    print("Ecuador MP-3, Wins-1, draws-1, loses-1, GF-4, GA-3, GD-1, Pts-4")
    print("Qatar MP-3, Wins-0, draws-0, loses-3, GF-1, GA-7, GD-(-6), Pts-0")
    print("England MP-3, Wins-2, draws-1, loses-0, GF-9, GA-2, GD-7, Pts-7")
    print("USA MP-3, Wins-1, draws-2, loses-0, GF-2, GA-1, GD-1, Pts-5")
    print("Iran MP-3, Wins-1, draws-0, loses-2, GF-4, GA-7, GD-(-3), Pts-3")
    print("Wales MP-3, Wins-0, draws-1, loses-2, GF-1, GA-6, GD-(-5), Pts-1")
    print("Argentina MP-3, Wins-2, draws-0, loses-1, GF-5, GA-2, GD-3, Pts-6")
    print("Poland MP-3, Wins-1, draws-1, loses-1, GF-2, GA-2, GD-0, Pts-4")
    print("Mexico MP-3, Wins-1, draws-1, loses-1, GF-2, GA-3, GD-(-1), Pts-4")
    print("Saudi Arabia MP-3, Wins-1, draws-0, loses-2, GF-3, GA-5, GD-(-2), Pts-3")
    print("France MP-3, Wins-2, draws-0, loses-1, GF-6, GA-3, GD-3, Pts-6")
    print("Australia MP-3, Wins-2, draws-0, loses-1, GF-3, GA-4, GD-(-1), Pts-6")
    print("Tunisia MP-3, Wins-1, draws-1, loses-1, GF-1, GA-1, GD-0, Pts-4")
    print("Denmark MP-3, Wins-0, draws-1, loses-2, GF-1, GA-3, GD-(-2), Pts-1")
    print("Japan MP-3, Wins-2, draws-0, loses-1, GF-4, GA-3, GD-1, Pts-6")
    print("Spain MP-3, Wins-1, draws-1, loses-1, GF-9, GA-3, GD-6, Pts-4")
    print("Germany MP-3, Wins-1, draws-1, loses-1, GF-6, GA-5, GD-1, Pts-4")
    print("Costa Rica MP-3, Wins-1, draws-0, loses-2, GF-3, GA-11, GD-(-8), Pts-3")
    print("Morocco MP-3, Wins-2, draws-1, loses-0, GF-4, GA-1, GD-3, Pts-7")
    print("Croatia MP-3, Wins-1, draws-2, loses-0, GF-4, GA-1, GD-3, Pts-5")
    print("Belgium MP-3, Wins-1, draws-1, loses-1, GF-1, GA-2, GD-(-1), Pts-4")
    print("Canada MP-3, Wins-0, draws-0, loses-3, GF-2, GA-7, GD-(-5), Pts-0")
    print("Brazil MP-3, Wins-2, draws-0, loses-1, GF-3, GA-1, GD-2, Pts-6")
    print("Switzerland MP-3, Wins-2, draws-0, loses-1, GF-4, GA-3, GD-1, Pts-6")
    print("Cameroon MP-3, Wins-1, draws-1, loses-1, GF-4, GA-4, GD-0, Pts-4")
    print("Serbia MP-3, Wins-0, draws-1, loses-2, GF-5, GA-8, GD-(-3), Pts-1")
    print("Portugal MP-3, Wins-2, draws-0, loses-1, GF-6, GA-4, GD-2, Pts-6")
    print("South Korea MP-3, Wins-1, draws-1, loses-1, GF-4, GA-4, GD-0, Pts-4")
    print("Uruguay MP-3, Wins-1, draws-1, loses-1, GF-2, GA-2, GD-0, Pts-4")
    print("Ghana MP-3, Wins-1, draws-0, loses-2, GF-5, GA-7, GD-(-2), Pts-3")
    print("\n")
#---------------------------------------------------------------------------------------------------------------------
class Groups():  
    def __init__(self, groupName, member1, member2, member3, member4, allMembers = None):
        self.groupName = groupName
        self.member1 = member1
        self.member2 = member2
        self.member3 = member3
        self.member4 = member4
        self.allMembers = [member1, member2, member3, member4]
Group_A = Groups('Group A', Netherlands.teamName, Sengal.teamName, Ecuador.teamName, Qatar.teamName)
Group_B = Groups('Group B', England.teamName, USA.teamName, Iran.teamName, Wales.teamName)
Group_C = Groups('Group C', Argentina.teamName, Poland.teamName, Mexico.teamName, Saudi_Arabia.teamName)
Group_D = Groups('Group D', France.teamName, Australia.teamName, Tunisia.teamName, Denmark.teamName)
Group_E = Groups('Group E', Japan.teamName, Spain.teamName, Germany.teamName, Costa_Rica.teamName)
Group_F = Groups('Group F', Morocco.teamName, Croatia.teamName, Belgium.teamName, Canada.teamName)
Group_G = Groups('Group G', Brazil.teamName, Switzerland.teamName, Cameroon.teamName, Serbia.teamName)
Group_H = Groups('Group H', Portugal.teamName, South_Korea.teamName, Uruguay.teamName, Ghana.teamName)
#---------------------------------------------------------------------------------------------------------------------
Netherlands_gr = (Group_A.member1, (Netherlands.Pts, Netherlands.GD))
Sengal_gr = (Group_A.member2, (Sengal.Pts, Sengal.GD))
Ecuador_gr = (Group_A.member3, (Ecuador.Pts, Ecuador.GD))
Qatar_gr = (Group_A.member4, (Qatar.Pts, Qatar.GD))
England_gr = (Group_B.member1, (England.Pts, England.GD))
USA_gr = (Group_B.member2, (USA.Pts, USA.GD))
Iran_gr = (Group_B.member3, (Iran.Pts, Iran.GD))
Wales_gr = (Group_B.member4, (Wales.Pts, Wales.GD))
Argentina_gr = (Group_C.member1, (Argentina.Pts, Argentina.GD))
Poland_gr = (Group_C.member2, (Poland.Pts, Poland.GD))
Mexico_gr = (Group_C.member3, (Mexico.Pts, Mexico.GD))
Saudi_Arabia_gr = (Group_C.member4, (Saudi_Arabia.Pts, Saudi_Arabia.GD))
France_gr = (Group_D.member1, (France.Pts, France.GD))
Australia_gr = (Group_D.member2, (Australia.Pts, Australia.GD))
Tunisia_gr = (Group_D.member3, (Tunisia.Pts, Tunisia.GD))
Denmark_gr = (Group_D.member4, (Denmark.Pts, Denmark.GD))
Japan_gr = (Group_E.member1, (Japan.Pts, Japan.GD))
Spain_gr = (Group_E.member2, (Spain.Pts, Spain.GD))
Germany_gr = (Group_E.member3, (Germany.Pts, Germany.GD))
Costa_Rica_gr = (Group_E.member4, (Costa_Rica.Pts, Costa_Rica.GD))
Morocco_gr = (Group_F.member1, (Morocco.Pts, Morocco.GD))
Croatia_gr = (Group_F.member2, (Croatia.Pts, Croatia.GD))
Belgium_gr = (Group_F.member3, (Belgium.Pts, Belgium.GD))
Canada_gr = (Group_F.member4, (Canada.Pts, Canada.GD))
Brazil_gr = (Group_G.member1, (Brazil.Pts, Brazil.GD))
Switzerland_gr = (Group_G.member2, (Switzerland.Pts, Switzerland.GD))
Cameroon_gr = (Group_G.member3, (Cameroon.Pts, Cameroon.GD))
Serbia_gr = (Group_G.member4, (Serbia.Pts, Serbia.GD))
Portugal_gr = (Group_H.member1, (Portugal.Pts, Portugal.GD))
South_Korea_gr = (Group_H.member2, (South_Korea.Pts, South_Korea.GD))
Uruguay_gr = (Group_H.member3, (Uruguay.Pts, Uruguay.GD))
Ghana_gr = (Group_H.member4, (Ghana.Pts, Ghana.GD))
#---------------------------------------------------------------------------------------------------------------------
gr_A = [
    Netherlands_gr, Sengal_gr, Ecuador_gr, Qatar_gr  
]
gr_B = [
      England_gr, USA_gr, Iran_gr, Wales_gr
]
gr_C = [
    Argentina_gr, Poland_gr, Mexico_gr, Saudi_Arabia_gr   
]
gr_D = [
    France_gr, Australia_gr, Tunisia_gr, Denmark_gr 
]
gr_E = [
    Japan_gr, Spain_gr, Germany_gr, Costa_Rica_gr
]
gr_F = [
    Morocco_gr, Croatia_gr, Belgium_gr, Canada_gr 
]
gr_G = [
    Brazil_gr, Switzerland_gr, Cameroon_gr, Serbia_gr
]
gr_H = [
    Portugal_gr, South_Korea_gr, Uruguay_gr, Ghana_gr
]
#---------------------------------------------------------------------------------------------------------------------
sort_gr_A = sorted(gr_A, key=lambda x: x[1], reverse = True)
sort_gr_B = sorted(gr_B, key=lambda x: x[1], reverse = True)
sort_gr_C = sorted(gr_C, key=lambda x: x[1], reverse = True)
sort_gr_D = sorted(gr_D, key=lambda x: x[1], reverse = True)
sort_gr_E = sorted(gr_E, key=lambda x: x[1], reverse = True)
sort_gr_F = sorted(gr_F, key=lambda x: x[1], reverse = True)
sort_gr_G = sorted(gr_G, key=lambda x: x[1], reverse = True)
sort_gr_H = sorted(gr_H, key=lambda x: x[1], reverse = True)
#---------------------------------------------------------------------------------------------------------------------    
print("-------Group stage--------")
print("Group A match results are:")
print(sort_gr_A)
print("-------------------------------------------------------------------------------------------------")
print("Group B match results are:")
print(sort_gr_B)
print("-------------------------------------------------------------------------------------------------")
print("Group C match results are:")
print(sort_gr_C)
print("-------------------------------------------------------------------------------------------------")
print("Group D match results are:")
print(sort_gr_D)
print("-------------------------------------------------------------------------------------------------")
print("Group E match results are:")
print(sort_gr_E)
print("-------------------------------------------------------------------------------------------------")
print("Group F match results are:")
print(sort_gr_F)
print("-------------------------------------------------------------------------------------------------")
print("Group G match results are:")
print(sort_gr_G)
print("-------------------------------------------------------------------------------------------------")
print("Group H match results are:")
print(sort_gr_H)
print("-------------------------------------------------------------------------------------------------")
print("\n")
#---------------------------------------------------------------------------------------------------------------------
class round16():
    def __init__(self, player1, player2, score = None, penalties = None, playerall = None):
            self.player1 = player1
            self.player2 = player2
round16_match1 = round16(sort_gr_A[0], sort_gr_B[1])
round16_match2 = round16(sort_gr_C[0], sort_gr_D[1])
round16_match3 = round16(sort_gr_E[0], sort_gr_F[1])
round16_match4 = round16(sort_gr_G[0], sort_gr_H[1])
round16_match5 = round16(sort_gr_D[0], sort_gr_C[1])
round16_match6 = round16(sort_gr_B[0], sort_gr_A[1])
round16_match7 = round16(sort_gr_F[0], sort_gr_E[1])
round16_match8 = round16(sort_gr_H[0], sort_gr_G[1])
#---------------------------------------------------------------------------------------------------------------------
x = round16_match1.player1
l = list(x).pop(0)
name = str(l).split(',')
Neth = name[0]

x = round16_match1.player2
l = list(x).pop(0)
name = str(l).split(',')
US = name[0]

x = round16_match2.player1
l = list(x).pop(0)
name = str(l).split(',')
Arg = name[0]

x = round16_match2.player2
l = list(x).pop(0)
name = str(l).split(',')
Aus = name[0]

x = round16_match3.player1
l = list(x).pop(0)
name = str(l).split(',')
Jap = name[0]

x = round16_match3.player2
l = list(x).pop(0)
name = str(l).split(',')
Cro = name[0]

x = round16_match4.player1
l = list(x).pop(0)
name = str(l).split(',')
Brz = name[0]

x = round16_match4.player2
l = list(x).pop(0)
name = str(l).split(',')
SKo = name[0]

x = round16_match5.player1
l = list(x).pop(0)
name = str(l).split(',')
Fra = name[0]

x = round16_match5.player2
l = list(x).pop(0)
name = str(l).split(',')
Pol = name[0]

x = round16_match6.player1
l = list(x).pop(0)
name = str(l).split(',')
Eng = name[0]

x = round16_match6.player2
l = list(x).pop(0)
name = str(l).split(',')
Sen = name[0]

x = round16_match7.player1
l = list(x).pop(0)
name = str(l).split(',')
Moro = name[0]

x = round16_match7.player2
l = list(x).pop(0)
name = str(l).split(',')
Spn = name[0]

x = round16_match8.player1
l = list(x).pop(0)
name = str(l).split(',')
Por = name[0]

x = round16_match8.player2
l = list(x).pop(0)
name = str(l).split(',')
Swi = name[0]
#---------------------------------------------------------------------------------------------------------------------
if (yesNo == "yes"):
    p1_score = input("Please enter in the score for " + str(Neth))
    p2_score = input("Please enter in the score for " + str(US))
    print("\n")

    p3_score = input("Please enter in the score for " + str(Arg))
    p4_score = input("Please enter in the score for " + str(Aus))
    print("\n")

    p5_score = input("Please enter in the score for " + str(Jap))
    p6_score = input("Please enter in the score for " + str(Cro))
    print("\n")

    p7_score = input("Please enter in the score for " + str(Brz))
    p8_score = input("Please enter in the score for " + str(SKo))
    print("\n")

    p9_score = input("Please enter in the score for " + str(Fra))
    p10_score = input("Please enter in the score for " + str(Pol))
    print("\n")

    p11_score = input("Please enter in the score for " + str(Eng))
    p12_score = input("Please enter in the score for " + str(Sen))
    print("\n")

    p13_score = input("Please enter in the score for " + str(Moro))
    p14_score = input("Please enter in the score for " + str(Spn))
    print("\n")

    p15_score = input("Please enter in the score for " + str(Por))
    p16_score = input("Please enter in the score for " + str(Swi))
    print("\n")
#---------------------------------------------------------------------------------------------------------------------
    if p1_score == p2_score:
        p1_score_pen = input("Please enter in the penalties for " + str(Neth))
        p2_score_pen = input("Please enter in the penalties for " + str(US))
        print("\n")
        
    if p3_score == p4_score:
        p3_score_pen = input("Please enter in the penalties for " + str(Arg))
        p4_score_pen = input("Please enter in the penalties for " + str(Aus))
        print("\n")
        
    if p5_score == p6_score:
        p5_score_pen = input("Please enter in the penalties for " + str(Jap))
        p6_score_pen = input("Please enter in the penalties for " + str(Cro))
        print("\n")
    
    if p7_score == p8_score:
        p7_score_pen = input("Please enter in the penalties for " + str(Brz))
        p8_score_pen = input("Please enter in the penalties for " + str(SKo))
        print("\n")
        
    if p9_score == p10_score:
        p9_score_pen = input("Please enter in the penalties for " + str(Fra))
        p10_score_pen = input("Please enter in the penalties for " + str(Pol))
        print("\n")
        
    if p11_score == p12_score:
        p11_score_pen = input("Please enter in the penalties for " + str(Eng))
        p12_score_pen = input("Please enter in the penalties for " + str(Sen))
        print("\n")
        
    if p13_score == p14_score:
        p13_score_pen = input("Please enter in the penalties for " + str(Moro))
        p14_score_pen = input("Please enter in the penalties for " + str(Spn))
        print("\n")
        
    if p15_score == p16_score:
        p15_score_pen = input("Please enter in the penalties for " + str(Por))
        p16_score_pen = input("Please enter in the penalties for " + str(Swi))
        print("\n")
#---------------------------------------------------------------------------------------------------------------------
    round16_match1.score = round16(p1_score, p2_score)
    round16_match2.score = round16(p3_score, p4_score)
    round16_match3.score = round16(p5_score, p6_score)
    round16_match4.score = round16(p7_score, p8_score)
    round16_match5.score = round16(p9_score, p10_score)
    round16_match6.score = round16(p11_score, p12_score)
    round16_match7.score = round16(p13_score, p14_score)
    round16_match8.score = round16(p15_score, p16_score)
#---------------------------------------------------------------------------------------------------------------------   
    round16_match1.penalties = round16(p1_score_pen, p2_score_pen)
    round16_match2.penalties = round16(p3_score_pen, p4_score_pen)
    round16_match3.penalties = round16(p5_score_pen, p6_score_pen)
    round16_match4.penalties = round16(p7_score_pen, p8_score_pen)
    round16_match5.penalties = round16(p9_score_pen, p10_score_pen)
    round16_match6.penalties = round16(p11_score_pen, p12_score_pen)
    round16_match7.penalties = round16(p13_score_pen, p14_score_pen)
    round16_match8.penalties = round16(p15_score_pen, p16_score_pen)
#--------------------------------------------------------------------------------------------------------------------- 
else:
    round16_match1.score = round16(3, 1)
    round16_match2.score = round16(2, 1)
    round16_match3.score = round16(1, 1)
    round16_match4.score = round16(4, 1)
    round16_match5.score = round16(3, 1)
    round16_match6.score = round16(3, 0)
    round16_match7.score = round16(0, 0)
    round16_match8.score = round16(6, 1)
    #---------------------------------------------------------------------------------------------------------------------
    round16_match1.penalties = round16(0, 0)
    round16_match2.penalties = round16(0, 0)
    round16_match3.penalties = round16(1, 3)
    round16_match4.penalties = round16(0, 0)
    round16_match5.penalties = round16(0, 0)
    round16_match6.penalties = round16(0, 0)
    round16_match7.penalties = round16(3, 0)
    round16_match8.penalties = round16(0, 0)
#---------------------------------------------------------------------------------------------------------------------
Netherlands_r16 = (Neth, (round16_match1.score.player1),  (round16_match1.penalties.player1))
USA_r16 = (US, (round16_match1.score.player2), (round16_match1.penalties.player2))
Argentina_r16 = (Arg,(round16_match2.score.player1), (round16_match2.penalties.player1))
Australia_r16 = (Aus, (round16_match2.score.player2), (round16_match2.penalties.player2))
Japan_r16 = (Jap, (round16_match3.score.player1), (round16_match3.penalties.player1))
Croatia_r16 = (Cro, (round16_match3.score.player2), (round16_match3.penalties.player2))
Brazil_r16 = (Brz, (round16_match4.score.player1), (round16_match4.penalties.player1))
South_Korea_r16 = (SKo, (round16_match4.score.player2), (round16_match4.penalties.player2))
France_r16 = (Fra, (round16_match5.score.player1), (round16_match5.penalties.player1))
Poland_r16 = (Pol, (round16_match5.score.player2), (round16_match5.penalties.player2))
England_r16 = (Eng, (round16_match6.score.player1), (round16_match6.penalties.player1))
Sengal_r16 = (Sen, (round16_match6.score.player2), (round16_match6.penalties.player2))
Morocco_r16 = (Moro, (round16_match7.score.player1), (round16_match7.penalties.player1))
Spain_r16 = (Spn, (round16_match7.score.player2), (round16_match7.penalties.player2))
Portugal_r16 = (Por, (round16_match8.score.player1), (round16_match8.penalties.player1))
Switzerland_r16 = (Swi, (round16_match8.score.player2), (round16_match8.penalties.player2))
#---------------------------------------------------------------------------------------------------------------------
r16_m1 = [
    Netherlands_r16, USA_r16
]
r16_m2 = [
    Argentina_r16, Australia_r16
]
r16_m3 = [
    Japan_r16, Croatia_r16
]
r16_m4 = [
    Brazil_r16, South_Korea_r16
]
r16_m5 = [
    France_r16, Poland_r16
]
r16_m6 = [
    England_r16, Sengal_r16
]
r16_m7 = [
    Morocco_r16, Spain_r16
]
r16_m8 = [
    Portugal_r16, Switzerland_r16
]
#---------------------------------------------------------------------------------------------------------------------
if Netherlands_r16[1]!=USA_r16[1]:
    sort_round16_match1 = sorted(r16_m1, key=lambda x: x[1], reverse = True)
elif Netherlands_r16[1] == USA_r16[1]:
    sort_round16_match1 = sorted(r16_m1, key=lambda x: x[2], reverse = True)

if Argentina_r16[1]!=Australia_r16[1]:
    sort_round16_match2 = sorted(r16_m2, key=lambda x: x[1], reverse = True)
elif Argentina_r16[1] == Australia_r16[1]:
    sort_round16_match2 = sorted(r16_m2, key=lambda x: x[2], reverse = True)

if Japan_r16[1]!=Croatia_r16[1]:
    sort_round16_match3 = sorted(r16_m3, key=lambda x: x[1], reverse = True)
elif Japan_r16[1] == Croatia_r16[1]:
    sort_round16_match3 = sorted(r16_m3, key=lambda x: x[2], reverse = True)

if Brazil_r16[1]!=South_Korea_r16[1]:
    sort_round16_match4 = sorted(r16_m4, key=lambda x: x[1], reverse = True)
elif Brazil_r16[1] == South_Korea_r16[1]:
    sort_round16_match4 = sorted(r16_m4, key=lambda x: x[2], reverse = True)

if France_r16[1]!=Poland_r16[1]:
    sort_round16_match5 = sorted(r16_m5, key=lambda x: x[1], reverse = True)
elif France_r16[1] == Poland_r16[1]:
    sort_round16_match5 = sorted(r16_m5, key=lambda x: x[2], reverse = True)

if England_r16[1]!=Sengal_r16[1]:
    sort_round16_match6 = sorted(r16_m6, key=lambda x: x[1], reverse = True)
elif England_r16[1] == Sengal_r16[1]:
    sort_round16_match6 = sorted(r16_m6, key=lambda x: x[2], reverse = True)

if Morocco_r16[1]!=Spain_r16[1]:
    sort_round16_match7 = sorted(r16_m7, key=lambda x: x[1], reverse = True)
elif Morocco_r16[1] == Spain_r16[1]:
    sort_round16_match7 = sorted(r16_m7, key=lambda x: x[2], reverse = True)

if Portugal_r16[1]!=Switzerland_r16[1]:
    sort_round16_match8 = sorted(r16_m8, key=lambda x: x[1], reverse = True)
elif Portugal_r16[1] == Switzerland_r16[1]:
    sort_round16_match8 = sorted(r16_m8, key=lambda x: x[2], reverse = True)
#---------------------------------------------------------------------------------------------------------------------    
print("-------round of 16--------")
print("The results for round of 16 match 1 are:")
print(sort_round16_match1)
print("------------------------------------------------------")
print("The results for round of 16 match 2 are:")
print(sort_round16_match2)
print("------------------------------------------------------")
print("The results for round of 16 match 3 are:")
print(sort_round16_match3)
print("------------------------------------------------------")
print("The results for round of 16 match 4 are:")
print(sort_round16_match4)
print("------------------------------------------------------")
print("The results for round of 16 match 5 are:")
print(sort_round16_match5)
print("------------------------------------------------------")
print("The results for round of 16 match 6 are:")
print(sort_round16_match6)
print("------------------------------------------------------")
print("The results for round of 16 match 7 are:")
print(sort_round16_match7)
print("------------------------------------------------------")
print("The results for round of 16 match 8 are:")
print("------------------------------------------------------")
print(sort_round16_match8)
print("------------------------------------------------------")
print("\n")
#---------------------------------------------------------------------------------------------------------------------
class qFinals():
    def __init__(self, q_player1, q_player2, score = None, penalties = None, q_playerall = None):
            self.q_player1 = q_player1
            self.q_player2 = q_player2
qFinals_match1 = qFinals(sort_round16_match1[0], sort_round16_match2[0])
qFinals_match2 = qFinals(sort_round16_match3[0], sort_round16_match4[0])
qFinals_match3 = qFinals(sort_round16_match5[0], sort_round16_match6[0])
qFinals_match4 = qFinals(sort_round16_match7[0], sort_round16_match8[0])
#---------------------------------------------------------------------------------------------------------------------
x = qFinals_match1.q_player1
l = list(x).pop(0)
name = str(l).split(',')
qF_P1 = name[0]

x = qFinals_match1.q_player2
l = list(x).pop(0)
name = str(l).split(',')
qF_P2 = name[0]

x = qFinals_match2.q_player1
l = list(x).pop(0)
name = str(l).split(',')
qF_P3 = name[0]

x = qFinals_match2.q_player2
l = list(x).pop(0)
name = str(l).split(',')
qF_P4 = name[0]

x = qFinals_match3.q_player1
l = list(x).pop(0)
name = str(l).split(',')
qF_P5 = name[0]

x = qFinals_match3.q_player2
l = list(x).pop(0)
name = str(l).split(',')
qF_P6 = name[0]

x = qFinals_match4.q_player1
l = list(x).pop(0)
name = str(l).split(',')
qF_P7 = name[0]

x = qFinals_match4.q_player2
l = list(x).pop(0)
name = str(l).split(',')
qF_P8 = name[0]
#---------------------------------------------------------------------------------------------------------------------
if (yesNo == "yes"):
    q_p1_m1_score = input("Please enter in the score for " + str(qF_P1))
    q_p2_m1_score = input("Please enter in the score for " + str(qF_P2))
    print("\n")
    
    q_p1_m2_score = input("Please enter in the score for " + str(qF_P3))
    q_p2_m2_score = input("Please enter in the score for " + str(qF_P4))
    print("\n")
    
    q_p1_m3_score = input("Please enter in the score for " + str(qF_P5))
    q_p2_m3_score = input("Please enter in the score for " + str(qF_P6))
    print("\n")
    
    q_p1_m4_score = input("Please enter in the score for " + str(qF_P7))
    q_p2_m4_score = input("Please enter in the score for " + str(qF_P8))
    print("\n")
 #---------------------------------------------------------------------------------------------------------------------
    if q_p1_m1_score == q_p2_m1_score:
        q_p1_m1_score_pen = input("Please enter in the penalties for " + str(qF_P1))
        q_p2_m1_score_pen = input("Please enter in the penalties for " + str(qF_P2))
        print("\n")
        
    if q_p1_m2_score == q_p2_m2_score:
        q_p1_m2_score_pen = input("Please enter in the penalties for " + str(qF_P3))
        q_p2_m2_score_pen = input("Please enter in the penalties for " + str(qF_P4))
        print("\n")
        
    if q_p1_m3_score == q_p2_m3_score:
        q_p1_m3_score_pen = input("Please enter in the penalties for " + str(qF_P5))
        q_p2_m3_score_pen = input("Please enter in the penalties for " + str(qF_P6))
        print("\n")
        
    if q_p1_m4_score == q_p2_m4_score:
        q_p1_m4_score_pen = input("Please enter in the penalties for " + str(qF_P7))
        q_p2_m4_score_pen = input("Please enter in the penalties for " + str(qF_P8))
        print("\n")
 #---------------------------------------------------------------------------------------------------------------------   
    qFinals_match1.score = qFinals(q_p1_m1_score, q_p2_m1_score)
    qFinals_match2.score = qFinals(q_p1_m2_score, q_p2_m2_score)
    qFinals_match3.score = qFinals(q_p1_m3_score, q_p2_m3_score)
    qFinals_match4.score = qFinals(q_p1_m4_score, q_p2_m4_score)
#---------------------------------------------------------------------------------------------------------------------
    qFinals_match1.penalties = qFinals(q_p1_m1_score_pen, q_p2_m1_score_pen)
    qFinals_match2.penalties = qFinals(q_p1_m2_score_pen, q_p2_m2_score_pen)
    qFinals_match3.penalties = qFinals(q_p1_m3_score_pen, q_p2_m3_score_pen)
    qFinals_match4.penalties = qFinals(q_p1_m4_score_pen, q_p2_m4_score_pen)
#---------------------------------------------------------------------------------------------------------------------
else:
    qFinals_match1.score = qFinals(2, 2)
    qFinals_match2.score = qFinals(1, 1)
    qFinals_match3.score = qFinals(2, 1)
    qFinals_match4.score = qFinals(1, 0)
    #---------------------------------------------------------------------------------------------------------------------
    qFinals_match1.penalties = qFinals(3, 4)
    qFinals_match2.penalties = qFinals(4, 2)
    qFinals_match3.penalties = qFinals(0, 0)
    qFinals_match4.penalties = qFinals(0, 0)
#---------------------------------------------------------------------------------------------------------------------
Netherlands_qFinals = (qF_P1, (qFinals_match1.score.q_player1), (qFinals_match1.penalties.q_player1))
Argentina_qFinals = (qF_P2, (qFinals_match1.score.q_player2), (qFinals_match1.penalties.q_player2))
Croatia_qFinals = (qF_P3, (qFinals_match2.score.q_player1), (qFinals_match2.penalties.q_player1))
Brazil_qFinals = (qF_P4, (qFinals_match2.score.q_player2), (qFinals_match2.penalties.q_player2))
England_qFinals = (qF_P5, (qFinals_match3.score.q_player1), (qFinals_match3.penalties.q_player1))
France_qFinals = (qF_P6, (qFinals_match3.score.q_player2), (qFinals_match3.penalties.q_player2))
Morocco_qFinals = (qF_P7, (qFinals_match4.score.q_player1), (qFinals_match4.penalties.q_player1))
Portugal_qFinals = (qF_P8, (qFinals_match4.score.q_player2), (qFinals_match4.penalties.q_player2))
#---------------------------------------------------------------------------------------------------------------------
qF_m1 = [
    Netherlands_qFinals, Argentina_qFinals
]
qF_m2 = [
    Croatia_qFinals, Brazil_qFinals
]
qF_m3 = [
    England_qFinals, France_qFinals
]
qF_m4 = [
    Morocco_qFinals, Portugal_qFinals
]
#---------------------------------------------------------------------------------------------------------------------
if Netherlands_qFinals[1]!=Argentina_qFinals[1]:
    sort_qFinals_match1 = sorted(qF_m1, key=lambda x: x[1], reverse = True)
elif Netherlands_qFinals[1] == Argentina_qFinals[1]:
    sort_qFinals_match1 = sorted(qF_m1, key=lambda x: x[2], reverse = True)

if Croatia_qFinals[1]!=Brazil_qFinals[1]:
    sort_qFinals_match2 = sorted(qF_m2, key=lambda x: x[1], reverse = True)
elif Croatia_qFinals[1] == Brazil_qFinals[1]:
    sort_qFinals_match2 = sorted(qF_m2, key=lambda x: x[2], reverse = True)

if England_qFinals[1]!=France_qFinals[1]:
    sort_qFinals_match3 = sorted(qF_m3, key=lambda x: x[1], reverse = True)
elif England_qFinals[1] == France_qFinals[1]:
    sort_qFinals_match3 = sorted(qF_m3, key=lambda x: x[2], reverse = True)

if Morocco_qFinals[1]!=Portugal_qFinals[1]:
    sort_qFinals_match4 = sorted(qF_m4, key=lambda x: x[1], reverse = True)
elif Morocco_qFinals[1] == Portugal_qFinals[1]:
    sort_qFinals_match4 = sorted(qF_m4, key=lambda x: x[2], reverse = True)
#---------------------------------------------------------------------------------------------------------------------    
print("-------quarter finals--------")
print("The results for quarter finals match 1 are:")
print(sort_qFinals_match1)
print("------------------------------------------------------")
print("The results for quarter finals match 2 are:")
print(sort_qFinals_match2)
print("------------------------------------------------------")
print("The results for quarter finals match 3 are:")
print(sort_qFinals_match3)
print("------------------------------------------------------")
print("The results for quarter finals match 4 are:")
print(sort_qFinals_match4)
print("------------------------------------------------------")
print("\n")
#---------------------------------------------------------------------------------------------------------------------
class sFinals():
    def __init__(self, s_player1, s_player2, score = None, penalties = None, s_playerall = None):
            self.s_player1 = s_player1
            self.s_player2 = s_player2
sFinals_match1 = sFinals(sort_qFinals_match1[0], sort_qFinals_match2[0])
sFinals_match2 = sFinals(sort_qFinals_match3[0], sort_qFinals_match4[0])
#---------------------------------------------------------------------------------------------------------------------
x = sFinals_match1.s_player1
l = list(x).pop(0)
name = str(l).split(',')
sF_P1 = name[0]

x = sFinals_match1.s_player2
l = list(x).pop(0)
name = str(l).split(',')
sF_P2 = name[0]

x = sFinals_match2.s_player1
l = list(x).pop(0)
name = str(l).split(',')
sF_P3 = name[0]

x = sFinals_match2.s_player2
l = list(x).pop(0)
name = str(l).split(',')
sF_P4 = name[0]
#---------------------------------------------------------------------------------------------------------------------
if (yesNo == "yes"):
    f_p1_m1_score = input("Please enter in the score for " + str(sF_P1))
    f_p2_m1_score = input("Please enter in the score for " + str(sF_P2))
    print("\n")
    
    f_p1_m2_score = input("Please enter in the score for " + str(sF_P3))
    f_p2_m2_score = input("Please enter in the score for " + str(sF_P4))
    print("\n")
#---------------------------------------------------------------------------------------------------------------------
    if f_p1_m1_score == f_p2_m1_score:
        f_p1_m1_score_pen = input("Please enter in the penalties for " + str(sF_P1))
        f_p2_m1_score_pen = input("Please enter in the penalties for " + str(sF_P2))
        print("\n")
        
    if f_p1_m2_score == f_p2_m2_score:
        f_p1_m2_score_pen = input("Please enter in the penalties for " + str(sF_P3))
        f_p2_m2_score_pen = input("Please enter in the penalties for " + str(sF_P4))
        print("\n")
#---------------------------------------------------------------------------------------------------------------------
    sFinals_match1.score = sFinals(f_p1_m1_score, f_p2_m1_score)
    sFinals_match2.score = sFinals(f_p1_m2_score, f_p2_m2_score)
#---------------------------------------------------------------------------------------------------------------------
    sFinals_match1.penalties = sFinals(f_p1_m1_score_pen, f_p2_m1_score_pen)
    sFinals_match2.penalties = sFinals(f_p1_m2_score_pen, f_p2_m2_score_pen)
#---------------------------------------------------------------------------------------------------------------------
else:
    sFinals_match1.score = sFinals(3, 0)
    sFinals_match2.score = sFinals(2, 0)
#---------------------------------------------------------------------------------------------------------------------
    sFinals_match1.penalties = sFinals(0, 0)
    sFinals_match2.penalties = sFinals(0, 0)
#---------------------------------------------------------------------------------------------------------------------
Argentina_sFinals = (sF_P1, (sFinals_match1.score.s_player1), (sFinals_match1.penalties.s_player1))
Croatia_sFinals = (sF_P2, (sFinals_match1.score.s_player2), (sFinals_match1.penalties.s_player2))
France_sFinals = (sF_P3, (sFinals_match2.score.s_player1), (sFinals_match2.penalties.s_player1))
Morocco_sFinals = (sF_P4, (sFinals_match2.score.s_player2), (sFinals_match2.penalties.s_player2))
#---------------------------------------------------------------------------------------------------------------------
sF_m1 = [
    Argentina_sFinals, Croatia_sFinals
]
sF_m2 = [
    France_sFinals, Morocco_sFinals
]
#---------------------------------------------------------------------------------------------------------------------
if Argentina_sFinals[1]!=Croatia_sFinals[1]:
    sort_sFinals_match1 = sorted(sF_m1, key=lambda x: x[1], reverse = True)
elif Argentina_sFinals[1] == Croatia_sFinals[1]:
    sort_sFinals_match1 = sorted(sF_m1, key=lambda x: x[2], reverse = True)

if France_sFinals[1]!=Morocco_sFinals[1]:
    sort_sFinals_match2 = sorted(sF_m2, key=lambda x: x[1], reverse = True)
elif France_sFinals[1] == Morocco_sFinals[1]:
    sort_sFinals_match2 = sorted(sF_m2, key=lambda x: x[2], reverse = True)
#---------------------------------------------------------------------------------------------------------------------
print("-------semi-Finals--------")
print("The semi-final results of the fisrt match is:")
print(sort_sFinals_match1)
print("------------------------------------------------------")
print("The semi-final results for the second match is:")
print(sort_sFinals_match2)
print("\n")
#---------------------------------------------------------------------------------------------------------------------
class Finals():
    def __init__(self, f_player1, f_player2, score = None, penalties = None, f_playerall = None):
            self.f_player1 = f_player1
            self.f_player2 = f_player2
Finals_match1 = Finals(sort_sFinals_match1[0], sort_sFinals_match2[0])
Finals_match2 = Finals(sort_sFinals_match1[1], sort_sFinals_match2[1])
#---------------------------------------------------------------------------------------------------------------------
x = Finals_match1.f_player1
l = list(x).pop(0)
name = str(l).split(',')
F_P1 = name[0]

x = Finals_match1.f_player2
l = list(x).pop(0)
name = str(l).split(',')
F_P2 = name[0]

x = Finals_match2.f_player1
l = list(x).pop(0)
name = str(l).split(',')
F_P3 = name[0]

x = Finals_match2.f_player2
l = list(x).pop(0)
name = str(l).split(',')
F_P4 = name[0]
#---------------------------------------------------------------------------------------------------------------------
if (yesNo == "yes"):
    f_p1_m1_final = input("Please enter in the score for " + str(F_P1))
    f_p2_m1_final = input("Please enter in the score for " + str(F_P2))
    print("\n")
    
    f_p1_m2_final = input("Please enter in the score for " + str(F_P3))
    f_p2_m2_final = input("Please enter in the score for " + str(F_P4))
#---------------------------------------------------------------------------------------------------------------------
    if f_p1_m1_final == f_p2_m1_final:
        f_p1_m1_final_pen = input("Please enter in the penalties for " + str(F_P1))
        f_p2_m1_final_pen = input("Please enter in the penalties for " + str(F_P2))
        print("\n")
        
    if f_p1_m2_final == f_p2_m2_final:
        f_p1_m2_final_pen = input("Please enter in the penalties for " + str(F_P3))
        f_p2_m2_final_pen = input("Please enter in the penalties for " + str(F_P4))
        print("\n")
#---------------------------------------------------------------------------------------------------------------------
    Finals_match1.score = Finals(f_p1_m1_final, f_p2_m1_final)
    Finals_match2.score = Finals(f_p1_m2_final, f_p2_m2_final)
#---------------------------------------------------------------------------------------------------------------------
    Finals_match1.penalties = Finals(f_p1_m1_final_pen, f_p2_m1_final_pen)
    Finals_match2.penalties = Finals(f_p1_m2_final_pen, f_p2_m2_final_pen)
#---------------------------------------------------------------------------------------------------------------------
else:
    Finals_match1.score = Finals(3, 3)
    Finals_match2.score = Finals(2, 1)
#---------------------------------------------------------------------------------------------------------------------
    Finals_match1.penalties = Finals(4, 2)
    Finals_match2.penalties = Finals(0, 0)
#---------------------------------------------------------------------------------------------------------------------
Argentina_Finals = (F_P1, (Finals_match1.score.f_player1), (Finals_match1.penalties.f_player1))
Croatia_Finals = (F_P3, (Finals_match2.score.f_player1), (Finals_match2.penalties.f_player1))
France_Finals = (F_P2, (Finals_match1.score.f_player2), (Finals_match1.penalties.f_player2))
Morocco_Finals = (F_P4, (Finals_match2.score.f_player2), (Finals_match2.penalties.f_player2))
#---------------------------------------------------------------------------------------------------------------------
F_m1 = [
    Argentina_Finals, France_Finals
]
F_m2 = [
    Croatia_Finals, Morocco_Finals
]
#---------------------------------------------------------------------------------------------------------------------
if Argentina_Finals[1]!=France_Finals[1]:
    sort_Finals_match1 = sorted(F_m1, key=lambda x: x[1], reverse = True)
elif Argentina_Finals[1] == France_Finals[1]:
    sort_Finals_match1 = sorted(F_m1, key=lambda x: x[2], reverse = True)
    
if Croatia_Finals[1]!=Morocco_Finals[1]:
    sort_Finals_match2 = sorted(F_m2, key=lambda x: x[1], reverse = True)
elif Croatia_Finals[1] == Morocco_Finals[1]:
    sort_Finals_match2 = sorted(F_m2, key=lambda x: x[2], reverse = True)
#---------------------------------------------------------------------------------------------------------------------  
print("-------Finals--------")
print("The match results for thrid and fourth are: ")
print(sort_Finals_match2)
print("------------------------------------------------------")
print("The match results for first and second are: ")
print(sort_Finals_match1)
print("******************************************************")
print("The final winner is: ")
print(sort_Finals_match1[0])
# Out:
# Do you want to input your own match results, yes/no: no
#
#
# The team stage results are:
# Netherlands MP-3, Wins-2, draws-1, loses-0 , GF-5, GA-1, GD-4, Pts-7
# Sengal MP-3, Wins-2, draws-0, loses-1, GF-5, GA-4, GD-1, Pts-6
# Ecuador MP-3, Wins-1, draws-1, loses-1, GF-4, GA-3, GD-1, Pts-4
# Qatar MP-3, Wins-0, draws-0, loses-3, GF-1, GA-7, GD-(-6), Pts-0
# England MP-3, Wins-2, draws-1, loses-0, GF-9, GA-2, GD-7, Pts-7
# USA MP-3, Wins-1, draws-2, loses-0, GF-2, GA-1, GD-1, Pts-5
# Iran MP-3, Wins-1, draws-0, loses-2, GF-4, GA-7, GD-(-3), Pts-3
# Wales MP-3, Wins-0, draws-1, loses-2, GF-1, GA-6, GD-(-5), Pts-1
# Argentina MP-3, Wins-2, draws-0, loses-1, GF-5, GA-2, GD-3, Pts-6
# Poland MP-3, Wins-1, draws-1, loses-1, GF-2, GA-2, GD-0, Pts-4
# Mexico MP-3, Wins-1, draws-1, loses-1, GF-2, GA-3, GD-(-1), Pts-4
# Saudi Arabia MP-3, Wins-1, draws-0, loses-2, GF-3, GA-5, GD-(-2), Pts-3
# France MP-3, Wins-2, draws-0, loses-1, GF-6, GA-3, GD-3, Pts-6
# ...
